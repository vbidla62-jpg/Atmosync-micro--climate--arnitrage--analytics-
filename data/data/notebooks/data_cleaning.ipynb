# %% [markdown]
# # Atmosync Data Cleaning - Day 3
# Vinay Bidla

# %%
import pandas as pd

df = pd.read_csv('../data/iot_sensor_data.csv')
print(df.head())

df_cleaned = df.dropna()
df_cleaned.to_csv('../data/iot_sensor_data_cleaned.csv', index=False)
print('Cleaned file saved!')
